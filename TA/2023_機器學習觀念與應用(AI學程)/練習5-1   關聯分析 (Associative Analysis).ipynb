# %% [markdown]
# #關聯分析 (Associative Analysis)
#
# <p align="center">
#     <img src="https://i.ibb.co/g4nNMRL/topic5-1-supervised-vs-unsupervised-learning.png" width="60%"/>
# </p>
#
#
#
#
#
# <p align="right">
#     <a href='https://kaumadiechamalka100.medium.com/apriori-algorithm-f7fb30793274'>
#     source
#     </a>
# </p>

# %% [markdown]
# ## 範例資料

# %%
# %%bash
# cat >  example.csv << EOL
# userID,transactionsID,items
# 1,1,Milk|Onion|Nutmeg|Kidney Beans|Eggs|Yogurt
# 2,2,Dill|Onion|Nutmeg|Eggs
# 1,3,Milk|Apple|Kidney Beans|Eggs
# 3,4,Milk|Unicorn|Corn|Kidney Beans|Yogurt
# 2,5,Corn|Onion|Kidney Beans|Ice cream|Eggs
# 3,6,Ice cream|Eggs|Yogurt
# 4,7,Corn|Kidney Beans|Ice cream|Eggs
# 1,8,Corn|Onion|Ice cream
# EOL

# %%
import pandas as pd
import warnings
warnings.simplefilter("ignore") #"error", "ignore", "always", "default", "module"

df = pd.read_csv('example.csv')
df
# Out:
#    userID  transactionsID                                       items
# 0       1               1  Milk|Onion|Nutmeg|Kidney Beans|Eggs|Yogurt
# 1       2               2                      Dill|Onion|Nutmeg|Eggs
# 2       1               3                Milk|Apple|Kidney Beans|Eggs
# 3       3               4       Milk|Unicorn|Corn|Kidney Beans|Yogurt
# 4       2               5      Corn|Onion|Kidney Beans|Ice cream|Eggs
# 5       3               6                       Ice cream|Eggs|Yogurt
# 6       4               7            Corn|Kidney Beans|Ice cream|Eggs
# 7       1               8                        Corn|Onion|Ice cream

# %% [markdown]
# ## 資料準備
# 在資料上通常會整理成 Adjacency Matrix(ii)或是Adjacency List(iii) 的格式。
# 下面為了方便講述使用圖論的示意圖，在 association rule 的情況下不完全一樣。
#
#
# <p align="center">
#     <img src="https://i.ibb.co/w7cJgXd/topic5-1-Digraph-G-ii-Adjacency-Matrix-of-G-iii-Adjacency-List-of-G-Considering-an.jpg" width="70%"/>
# </p>
#
# <p align="right">
#     <a href='https://www.researchgate.net/figure/Fig-3-i-Digraph-G-ii-Adjacency-Matrix-of-G-iii-Adjacency-List-of-G-Considering-an_fig1_272172339'>
#     source
#     </a>
# </p>
#
# 下圖是在 association rule 時常看到的格式，是使用 Adjacency Matrix 的表示方式。
#
# <p align="center">
#     <img src="https://i.ibb.co/zxxMkRG/topic5-1-tran-item-matrix.png" width="80%"/>
# </p>
#
#
#
#
#
# <p align="right">
#     <a href='https://www.kaggle.com/code/keitazoumana/comparative-analysis-between-apriori-and-fp-growth'>
#     source
#     </a>
# </p>

# %% [markdown]
# ## 定義目標
# 在進行 association rule 前你需要先定義你算頻率的一筆代表的是甚麼，你要 mining 甚麼的 pattern。以上面的範例來說:

# %% [markdown]
# ### transactions - items
# 一筆是代表一個交易，找商品間的 pattern。

# %%
df_tran = df[['transactionsID', 'items']]
df_tran
# Out:
#    transactionsID                                       items
# 0               1  Milk|Onion|Nutmeg|Kidney Beans|Eggs|Yogurt
# 1               2                      Dill|Onion|Nutmeg|Eggs
# 2               3                Milk|Apple|Kidney Beans|Eggs
# 3               4       Milk|Unicorn|Corn|Kidney Beans|Yogurt
# 4               5      Corn|Onion|Kidney Beans|Ice cream|Eggs
# 5               6                       Ice cream|Eggs|Yogurt
# 6               7            Corn|Kidney Beans|Ice cream|Eggs
# 7               8                        Corn|Onion|Ice cream

# %%
items_ls = df_tran['items'].str.split('|').tolist()
items_ls
# Out:
# [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Dill', 'Onion', 'Nutmeg', 'Eggs'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs'],
#  ['Ice cream', 'Eggs', 'Yogurt'],
#  ['Corn', 'Kidney Beans', 'Ice cream', 'Eggs'],
#  ['Corn', 'Onion', 'Ice cream']]

# %% [markdown]
# 使用 [mlxtend.preprocessing.transactionencoder](https://rasbt.github.io/mlxtend/api_subpackages/mlxtend.preprocessing/#transactionencoder)

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(items_ls).transform(items_ls)
df_tran_matrix = pd.DataFrame(te_ary, columns=te.columns_)
df_tran_matrix.set_index(df_tran['transactionsID'], inplace=True)
df_tran_matrix
# Out:
#                 Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  \
# transactionsID
# 1               False  False  False   True      False          True   True
# 2               False  False   True   True      False         False  False
# 3                True  False  False   True      False          True   True
# 4               False   True  False  False      False          True   True
# 5               False   True  False   True       True          True  False
# 6               False  False  False   True       True         False  False
# 7               False   True  False   True       True          True  False
# 8               False   True  False  False       True         False  False
#
#                 Nutmeg  Onion  Unicorn  Yogurt
# transactionsID
# 1                 True   True    False    True
# 2                 True   True    False   False
# 3                False  False    False   False
# 4                False  False     True    True
# 5                False   True    False   False
# 6                False  False    False    True
# 7                False  False    False   False
# 8                False   True    False   False

# %% [markdown]
# ### users - items
# 一筆代表一個 user，找商品間的 pattern。

# %%
df_user = df[['userID', 'items']]
df_user
# Out:
#    userID                                       items
# 0       1  Milk|Onion|Nutmeg|Kidney Beans|Eggs|Yogurt
# 1       2                      Dill|Onion|Nutmeg|Eggs
# 2       1                Milk|Apple|Kidney Beans|Eggs
# 3       3       Milk|Unicorn|Corn|Kidney Beans|Yogurt
# 4       2      Corn|Onion|Kidney Beans|Ice cream|Eggs
# 5       3                       Ice cream|Eggs|Yogurt
# 6       4            Corn|Kidney Beans|Ice cream|Eggs
# 7       1                        Corn|Onion|Ice cream

# %%
# 移除重複 user
df_user['items_new'] = df_user.groupby('userID')['items'].transform(lambda x: '|'.join(x))
df_user.drop('items', axis=1, inplace=True)
df_user.drop_duplicates(inplace=True)
df_user
# Out:
#    userID                                          items_new
# 0       1  Milk|Onion|Nutmeg|Kidney Beans|Eggs|Yogurt|Mil...
# 1       2  Dill|Onion|Nutmeg|Eggs|Corn|Onion|Kidney Beans...
# 3       3  Milk|Unicorn|Corn|Kidney Beans|Yogurt|Ice crea...
# 6       4                   Corn|Kidney Beans|Ice cream|Eggs

# %%
# 移除重複 item
df_user['items_new'] = df_user['items_new'].apply(lambda x: list(set(x.split('|'))))
df_user
# Out:
#    userID                                          items_new
# 0       1  [Corn, Kidney Beans, Eggs, Onion, Ice cream, Y...
# 1       2  [Corn, Kidney Beans, Eggs, Onion, Ice cream, N...
# 3       3  [Corn, Kidney Beans, Eggs, Unicorn, Ice cream,...
# 6       4              [Corn, Eggs, Kidney Beans, Ice cream]

# %% [markdown]
# 使用 [mlxtend.preprocessing.transactionencoder](https://rasbt.github.io/mlxtend/api_subpackages/mlxtend.preprocessing/#transactionencoder)

# %%
# 轉成 list
items_ls = df_user['items_new'].tolist()
items_ls
# Out:
# [['Corn',
#   'Kidney Beans',
#   'Eggs',
#   'Onion',
#   'Ice cream',
#   'Yogurt',
#   'Milk',
#   'Nutmeg',
#   'Apple'],
#  ['Corn', 'Kidney Beans', 'Eggs', 'Onion', 'Ice cream', 'Nutmeg', 'Dill'],
#  ['Corn', 'Kidney Beans', 'Eggs', 'Unicorn', 'Ice cream', 'Yogurt', 'Milk'],
#  ['Corn', 'Eggs', 'Kidney Beans', 'Ice cream']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(items_ls).transform(items_ls)
df_user_matrix = pd.DataFrame(te_ary, columns=te.columns_)
df_user_matrix.set_index(df_user['userID'], inplace=True)
df_user_matrix
# Out:
#         Apple  Corn   Dill  Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  \
# userID
# 1        True  True  False  True       True          True   True    True
# 2       False  True   True  True       True          True  False    True
# 3       False  True  False  True       True          True   True   False
# 4       False  True  False  True       True          True  False   False
#
#         Onion  Unicorn  Yogurt
# userID
# 1        True    False    True
# 2        True    False   False
# 3       False     True    True
# 4       False    False   False

# %% [markdown]
# ### items - user
# 一筆代表一個商品，找 user 間的 pattern。

# %%
df_user
# Out:
#    userID                                          items_new
# 0       1  [Corn, Kidney Beans, Eggs, Onion, Ice cream, Y...
# 1       2  [Corn, Kidney Beans, Eggs, Onion, Ice cream, N...
# 3       3  [Corn, Kidney Beans, Eggs, Unicorn, Ice cream,...
# 6       4              [Corn, Eggs, Kidney Beans, Ice cream]

# %%
# user - 商品清單
all_items = [(uid, i) for uid, items in df_user[['userID', 'items_new']].values for i in items]
df_items = pd.DataFrame(all_items, columns=['userID', 'items'])
df_items
# Out:
#     userID         items
# 0        1          Corn
# 1        1  Kidney Beans
# 2        1          Eggs
# 3        1         Onion
# 4        1     Ice cream
# 5        1        Yogurt
# 6        1          Milk
# 7        1        Nutmeg
# 8        1         Apple
# 9        2          Corn
# 10       2  Kidney Beans
# 11       2          Eggs
# 12       2         Onion
# 13       2     Ice cream
# 14       2        Nutmeg
# 15       2          Dill
# 16       3          Corn
# 17       3  Kidney Beans
# 18       3          Eggs
# 19       3       Unicorn
# 20       3     Ice cream
# 21       3        Yogurt
# 22       3          Milk
# 23       4          Corn
# 24       4          Eggs
# 25       4  Kidney Beans
# 26       4     Ice cream

# %%
df_items['buy'] = 1
df_item_matrix = df_items.pivot(index='items', columns='userID', values='buy')
df_item_matrix.fillna(0, inplace=True)
df_item_matrix = df_item_matrix.astype(bool)
df_item_matrix
# Out:
# userID            1      2      3      4
# items
# Apple          True  False  False  False
# Corn           True   True   True   True
# Dill          False   True  False  False
# Eggs           True   True   True   True
# Ice cream      True   True   True   True
# Kidney Beans   True   True   True   True
# Milk           True  False   True  False
# Nutmeg         True   True  False  False
# Onion          True   True  False  False
# Unicorn       False  False   True  False
# Yogurt         True  False   True  False

# %% [markdown]
# ## 演算法

# %% [markdown]
# ### Apriori
#
# #### **Support:**
# Support is the frequency of A or how frequently an item appears in the dataset. It is defined as the fraction of the transaction T that contains the itemset X. If there are X datasets, then for transactions T, it can be written as:
#
# <br>
# <div align="center">
#
# $Supp(X) = Freq(X) / T$
#
# </div>
# <br>
#
#
# #### **Confidence:**
# Confidence indicates how often the rule has been found to be true. Or how often the items X and Y occur together in the dataset when the occurrence of X is already given. It is the ratio of the transaction that contains X and Y to the number of records that contain X.
#
# <br>
# <div align="center">
#
# $Confidence = Freq(X,Y) / Freq(X)$
#
# </div>
# <br>
#
#
# #### **Lift:**
# It is the strength of any rule, which can be defined as below formula: It is the ratio of the observed support measure and expected support if X and Y are independent of each other. It has three possible values:
#
# <br>
# <div align="center">
#
# $Lift = Supp(X,Y) / Supp(X)*Supp(Y)$
#
# </div>
# <br>
#
# - `Lift= 1`: The probability of occurrence of antecedent and consequent is independent of each other.
# - `Lift>1`: It determines the degree to which the two itemsets are dependent to each other.
# - `Lift<1`: It tells us that one item is a substitute for other items, which means one item has a negative effect on another.
#
#
#
# <p align="right">
#     <a href='https://www.geeksforgeeks.org/associative-classification-in-data-mining/'>
#     source
#     </a>
# </p>

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# #### Step1: 跑演算法
# 這部分事前對 support 做篩選，當資料集大時可以透過提高 support 門檻加快速度。

# %%
# 自己大概抓一下要設定多少
apriori(df_tran_matrix, min_support=0.5, use_colnames=True)
# Out:
#    support              itemsets
# 0    0.500                (Corn)
# 1    0.750                (Eggs)
# 2    0.500           (Ice cream)
# 3    0.625        (Kidney Beans)
# 4    0.500               (Onion)
# 5    0.500  (Eggs, Kidney Beans)

# %%
# 設一個極小的門檻作為 min_support 可以列出所有結果
aprior_result = apriori(df_tran_matrix, min_support=0.00001, use_colnames=True)
aprior_result
# Out:
#      support                                           itemsets
# 0      0.125                                            (Apple)
# 1      0.500                                             (Corn)
# 2      0.125                                             (Dill)
# 3      0.750                                             (Eggs)
# 4      0.500                                        (Ice cream)
# ..       ...                                                ...
# 122    0.125          (Kidney Beans, Eggs, Onion, Yogurt, Milk)
# 123    0.125        (Kidney Beans, Eggs, Onion, Yogurt, Nutmeg)
# 124    0.125                (Eggs, Onion, Yogurt, Milk, Nutmeg)
# 125    0.125        (Kidney Beans, Onion, Yogurt, Milk, Nutmeg)
# 126    0.125  (Kidney Beans, Eggs, Onion, Yogurt, Milk, Nutmeg)
#
# [127 rows x 2 columns]

# %% [markdown]
# #### Step2: 計算評估指標
#
# - antecedents 前因
# - consequents 後果

# %%
aprior_rules = association_rules(aprior_result)
aprior_rules
# Out:
#                 antecedents                           consequents  \
# 0                   (Apple)                                (Eggs)
# 1                   (Apple)                        (Kidney Beans)
# 2                   (Apple)                                (Milk)
# 3                 (Unicorn)                                (Corn)
# 4                    (Dill)                                (Eggs)
# ..                      ...                                   ...
# 400  (Nutmeg, Kidney Beans)           (Yogurt, Milk, Eggs, Onion)
# 401         (Yogurt, Onion)    (Milk, Nutmeg, Eggs, Kidney Beans)
# 402           (Milk, Onion)  (Yogurt, Nutmeg, Eggs, Kidney Beans)
# 403        (Yogurt, Nutmeg)     (Milk, Eggs, Kidney Beans, Onion)
# 404          (Milk, Nutmeg)   (Yogurt, Eggs, Kidney Beans, Onion)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                 0.125               0.750    0.125         1.0  1.333333
# 1                 0.125               0.625    0.125         1.0  1.600000
# 2                 0.125               0.375    0.125         1.0  2.666667
# 3                 0.125               0.500    0.125         1.0  2.000000
# 4                 0.125               0.750    0.125         1.0  1.333333
# ..                  ...                 ...      ...         ...       ...
# 400               0.125               0.125    0.125         1.0  8.000000
# 401               0.125               0.125    0.125         1.0  8.000000
# 402               0.125               0.125    0.125         1.0  8.000000
# 403               0.125               0.125    0.125         1.0  8.000000
# 404               0.125               0.125    0.125         1.0  8.000000
#
#      leverage  conviction  zhangs_metric
# 0    0.031250         inf       0.285714
# 1    0.046875         inf       0.428571
# 2    0.078125         inf       0.714286
# 3    0.062500         inf       0.571429
# 4    0.031250         inf       0.285714
# ..        ...         ...            ...
# 400  0.109375         inf       1.000000
# 401  0.109375         inf       1.000000
# 402  0.109375         inf       1.000000
# 403  0.109375         inf       1.000000
# 404  0.109375         inf       1.000000
#
# [405 rows x 10 columns]

# %% [markdown]
# #### Step3: 篩選出 pattern (pandas)

# %%
aprior_rules[
    (aprior_rules['confidence'] > 0.9) &
    (aprior_rules['lift'] > 5)
    ]
# Out:
#                     antecedents                           consequents  \
# 33                 (Milk, Corn)                             (Unicorn)
# 36                    (Unicorn)                          (Milk, Corn)
# 39               (Yogurt, Corn)                             (Unicorn)
# 42                    (Unicorn)                        (Yogurt, Corn)
# 109  (Milk, Corn, Kidney Beans)                             (Unicorn)
# ..                          ...                                   ...
# 400      (Nutmeg, Kidney Beans)           (Yogurt, Milk, Eggs, Onion)
# 401             (Yogurt, Onion)    (Milk, Nutmeg, Eggs, Kidney Beans)
# 402               (Milk, Onion)  (Yogurt, Nutmeg, Eggs, Kidney Beans)
# 403            (Yogurt, Nutmeg)     (Milk, Eggs, Kidney Beans, Onion)
# 404              (Milk, Nutmeg)   (Yogurt, Eggs, Kidney Beans, Onion)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 33                0.125               0.125    0.125         1.0   8.0
# 36                0.125               0.125    0.125         1.0   8.0
# 39                0.125               0.125    0.125         1.0   8.0
# 42                0.125               0.125    0.125         1.0   8.0
# 109               0.125               0.125    0.125         1.0   8.0
# ..                  ...                 ...      ...         ...   ...
# 400               0.125               0.125    0.125         1.0   8.0
# 401               0.125               0.125    0.125         1.0   8.0
# 402               0.125               0.125    0.125         1.0   8.0
# 403               0.125               0.125    0.125         1.0   8.0
# 404               0.125               0.125    0.125         1.0   8.0
#
#      leverage  conviction  zhangs_metric  antecedent_len
# 33   0.109375         inf            1.0               2
# 36   0.109375         inf            1.0               1
# 39   0.109375         inf            1.0               2
# 42   0.109375         inf            1.0               1
# 109  0.109375         inf            1.0               3
# ..        ...         ...            ...             ...
# 400  0.109375         inf            1.0               2
# 401  0.109375         inf            1.0               2
# 402  0.109375         inf            1.0               2
# 403  0.109375         inf            1.0               2
# 404  0.109375         inf            1.0               2
#
# [94 rows x 11 columns]

# %%
# 建立 關聯的 item 數
aprior_rules['antecedent_len'] = aprior_rules['antecedents'].str.len()

# %%
aprior_rules[
    (aprior_rules['antecedent_len'] > 3) &
    (aprior_rules['confidence'] > 0.9) &
    (aprior_rules['lift'] > 5)
    ]
# Out:
#                               antecedents             consequents  \
# 246    (Yogurt, Milk, Corn, Kidney Beans)               (Unicorn)
# 369   (Yogurt, Eggs, Kidney Beans, Onion)          (Milk, Nutmeg)
# 370     (Milk, Eggs, Kidney Beans, Onion)        (Yogurt, Nutmeg)
# 373  (Yogurt, Nutmeg, Eggs, Kidney Beans)           (Milk, Onion)
# 374    (Milk, Nutmeg, Eggs, Kidney Beans)         (Yogurt, Onion)
# 379           (Yogurt, Milk, Eggs, Onion)  (Nutmeg, Kidney Beans)
#
#      antecedent support  consequent support  support  confidence  lift  \
# 246               0.125               0.125    0.125         1.0   8.0
# 369               0.125               0.125    0.125         1.0   8.0
# 370               0.125               0.125    0.125         1.0   8.0
# 373               0.125               0.125    0.125         1.0   8.0
# 374               0.125               0.125    0.125         1.0   8.0
# 379               0.125               0.125    0.125         1.0   8.0
#
#      leverage  conviction  zhangs_metric  antecedent_len
# 246  0.109375         inf            1.0               4
# 369  0.109375         inf            1.0               4
# 370  0.109375         inf            1.0               4
# 373  0.109375         inf            1.0               4
# 374  0.109375         inf            1.0               4
# 379  0.109375         inf            1.0               4

# %% [markdown]
# #### items-user
# 也可以用 items-user 去做

# %%
# 改一下欄位名稱
df_item_matrix.columns = [f'user{i}' for i in df_item_matrix.columns]

# %%
df_item_matrix
# Out:
#               user1  user2  user3  user4
# items
# Apple          True  False  False  False
# Corn           True   True   True   True
# Dill          False   True  False  False
# Eggs           True   True   True   True
# Ice cream      True   True   True   True
# Kidney Beans   True   True   True   True
# Milk           True  False   True  False
# Nutmeg         True   True  False  False
# Onion          True   True  False  False
# Unicorn       False  False   True  False
# Yogurt         True  False   True  False

# %%
aprior_result_user = apriori(df_item_matrix, min_support=0.2, use_colnames=True)
aprior_result_user
# Out:
#      support                      itemsets
# 0   0.818182                       (user1)
# 1   0.636364                       (user2)
# 2   0.636364                       (user3)
# 3   0.363636                       (user4)
# 4   0.545455                (user2, user1)
# 5   0.545455                (user3, user1)
# 6   0.363636                (user4, user1)
# 7   0.363636                (user2, user3)
# 8   0.363636                (user2, user4)
# 9   0.363636                (user3, user4)
# 10  0.363636         (user2, user3, user1)
# 11  0.363636         (user2, user4, user1)
# 12  0.363636         (user3, user4, user1)
# 13  0.363636         (user2, user3, user4)
# 14  0.363636  (user2, user3, user4, user1)

# %%
association_rules(aprior_result_user)
# Out:
#               antecedents            consequents  antecedent support  \
# 0                 (user2)                (user1)            0.636364
# 1                 (user3)                (user1)            0.636364
# 2                 (user4)                (user1)            0.363636
# 3                 (user4)                (user2)            0.363636
# 4                 (user4)                (user3)            0.363636
# 5          (user2, user3)                (user1)            0.363636
# 6          (user2, user4)                (user1)            0.363636
# 7          (user4, user1)                (user2)            0.363636
# 8                 (user4)         (user2, user1)            0.363636
# 9          (user3, user4)                (user1)            0.363636
# 10         (user4, user1)                (user3)            0.363636
# 11                (user4)         (user3, user1)            0.363636
# 12         (user2, user3)                (user4)            0.363636
# 13         (user2, user4)                (user3)            0.363636
# 14         (user3, user4)                (user2)            0.363636
# 15                (user4)         (user2, user3)            0.363636
# 16  (user2, user3, user4)                (user1)            0.363636
# 17  (user2, user3, user1)                (user4)            0.363636
# 18  (user2, user4, user1)                (user3)            0.363636
# 19  (user3, user4, user1)                (user2)            0.363636
# 20         (user2, user3)         (user4, user1)            0.363636
# 21         (user2, user4)         (user3, user1)            0.363636
# 22         (user3, user4)         (user2, user1)            0.363636
# 23         (user4, user1)         (user2, user3)            0.363636
# 24                (user4)  (user2, user3, user1)            0.363636
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.818182  0.545455    0.857143  1.047619  0.024793    1.272727
# 1             0.818182  0.545455    0.857143  1.047619  0.024793    1.272727
# 2             0.818182  0.363636    1.000000  1.222222  0.066116         inf
# 3             0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 4             0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 5             0.818182  0.363636    1.000000  1.222222  0.066116         inf
# 6             0.818182  0.363636    1.000000  1.222222  0.066116         inf
# 7             0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 8             0.545455  0.363636    1.000000  1.833333  0.165289         inf
# 9             0.818182  0.363636    1.000000  1.222222  0.066116         inf
# 10            0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 11            0.545455  0.363636    1.000000  1.833333  0.165289         inf
# 12            0.363636  0.363636    1.000000  2.750000  0.231405         inf
# 13            0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 14            0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 15            0.363636  0.363636    1.000000  2.750000  0.231405         inf
# 16            0.818182  0.363636    1.000000  1.222222  0.066116         inf
# 17            0.363636  0.363636    1.000000  2.750000  0.231405         inf
# 18            0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 19            0.636364  0.363636    1.000000  1.571429  0.132231         inf
# 20            0.363636  0.363636    1.000000  2.750000  0.231405         inf
# 21            0.545455  0.363636    1.000000  1.833333  0.165289         inf
# 22            0.545455  0.363636    1.000000  1.833333  0.165289         inf
# 23            0.363636  0.363636    1.000000  2.750000  0.231405         inf
# 24            0.363636  0.363636    1.000000  2.750000  0.231405         inf
#
#     zhangs_metric
# 0        0.125000
# 1        0.125000
# 2        0.285714
# 3        0.571429
# 4        0.571429
# 5        0.285714
# 6        0.285714
# 7        0.571429
# 8        0.714286
# 9        0.285714
# 10       0.571429
# 11       0.714286
# 12       1.000000
# 13       0.571429
# 14       0.571429
# 15       1.000000
# 16       0.285714
# 17       1.000000
# 18       0.571429
# 19       0.571429
# 20       1.000000
# 21       0.714286
# 22       0.714286
# 23       1.000000
# 24       1.000000

# %% [markdown]
# ### FP-Growth
# 加速版 aprior

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
fpgrowth_result = fpgrowth(df_tran_matrix, min_support=0.2, use_colnames=True)
fpgrowth_result
# Out:
#     support                               itemsets
# 0     0.750                                 (Eggs)
# 1     0.625                         (Kidney Beans)
# 2     0.500                                (Onion)
# 3     0.375                               (Yogurt)
# 4     0.375                                 (Milk)
# 5     0.250                               (Nutmeg)
# 6     0.500                                 (Corn)
# 7     0.500                            (Ice cream)
# 8     0.500                   (Eggs, Kidney Beans)
# 9     0.375                          (Eggs, Onion)
# 10    0.250                  (Onion, Kidney Beans)
# 11    0.250            (Eggs, Onion, Kidney Beans)
# 12    0.250                 (Yogurt, Kidney Beans)
# 13    0.250                         (Yogurt, Eggs)
# 14    0.375                   (Milk, Kidney Beans)
# 15    0.250                         (Yogurt, Milk)
# 16    0.250                           (Milk, Eggs)
# 17    0.250           (Yogurt, Milk, Kidney Beans)
# 18    0.250             (Milk, Eggs, Kidney Beans)
# 19    0.250                        (Nutmeg, Onion)
# 20    0.250                         (Nutmeg, Eggs)
# 21    0.250                  (Nutmeg, Eggs, Onion)
# 22    0.375                   (Corn, Kidney Beans)
# 23    0.375                      (Corn, Ice cream)
# 24    0.250                          (Corn, Onion)
# 25    0.250                           (Corn, Eggs)
# 26    0.250        (Corn, Kidney Beans, Ice cream)
# 27    0.250               (Corn, Onion, Ice cream)
# 28    0.250             (Corn, Eggs, Kidney Beans)
# 29    0.250                (Corn, Eggs, Ice cream)
# 30    0.250  (Corn, Eggs, Kidney Beans, Ice cream)
# 31    0.375                      (Eggs, Ice cream)
# 32    0.250                     (Onion, Ice cream)
# 33    0.250              (Kidney Beans, Ice cream)
# 34    0.250        (Eggs, Kidney Beans, Ice cream)

# %%
association_rules(fpgrowth_result)
# Out:
#                         antecedents                consequents  \
# 0                    (Kidney Beans)                     (Eggs)
# 1             (Onion, Kidney Beans)                     (Eggs)
# 2                            (Milk)             (Kidney Beans)
# 3                    (Yogurt, Milk)             (Kidney Beans)
# 4            (Yogurt, Kidney Beans)                     (Milk)
# 5                      (Milk, Eggs)             (Kidney Beans)
# 6                          (Nutmeg)                    (Onion)
# 7                          (Nutmeg)                     (Eggs)
# 8                    (Nutmeg, Eggs)                    (Onion)
# 9                   (Nutmeg, Onion)                     (Eggs)
# 10                         (Nutmeg)              (Eggs, Onion)
# 11        (Kidney Beans, Ice cream)                     (Corn)
# 12                    (Corn, Onion)                (Ice cream)
# 13               (Onion, Ice cream)                     (Corn)
# 14                     (Corn, Eggs)             (Kidney Beans)
# 15                     (Corn, Eggs)                (Ice cream)
# 16       (Corn, Eggs, Kidney Beans)                (Ice cream)
# 17          (Corn, Eggs, Ice cream)             (Kidney Beans)
# 18  (Corn, Kidney Beans, Ice cream)                     (Eggs)
# 19  (Eggs, Kidney Beans, Ice cream)                     (Corn)
# 20                     (Corn, Eggs)  (Kidney Beans, Ice cream)
# 21        (Kidney Beans, Ice cream)               (Corn, Eggs)
# 22        (Kidney Beans, Ice cream)                     (Eggs)
#
#     antecedent support  consequent support  support  confidence      lift  \
# 0                0.625               0.750    0.500         0.8  1.066667
# 1                0.250               0.750    0.250         1.0  1.333333
# 2                0.375               0.625    0.375         1.0  1.600000
# 3                0.250               0.625    0.250         1.0  1.600000
# 4                0.250               0.375    0.250         1.0  2.666667
# 5                0.250               0.625    0.250         1.0  1.600000
# 6                0.250               0.500    0.250         1.0  2.000000
# 7                0.250               0.750    0.250         1.0  1.333333
# 8                0.250               0.500    0.250         1.0  2.000000
# 9                0.250               0.750    0.250         1.0  1.333333
# 10               0.250               0.375    0.250         1.0  2.666667
# 11               0.250               0.500    0.250         1.0  2.000000
# 12               0.250               0.500    0.250         1.0  2.000000
# 13               0.250               0.500    0.250         1.0  2.000000
# 14               0.250               0.625    0.250         1.0  1.600000
# 15               0.250               0.500    0.250         1.0  2.000000
# 16               0.250               0.500    0.250         1.0  2.000000
# 17               0.250               0.625    0.250         1.0  1.600000
# 18               0.250               0.750    0.250         1.0  1.333333
# 19               0.250               0.500    0.250         1.0  2.000000
# 20               0.250               0.250    0.250         1.0  4.000000
# 21               0.250               0.250    0.250         1.0  4.000000
# 22               0.250               0.750    0.250         1.0  1.333333
#
#     leverage  conviction  zhangs_metric
# 0   0.031250        1.25       0.166667
# 1   0.062500         inf       0.333333
# 2   0.140625         inf       0.600000
# 3   0.093750         inf       0.500000
# 4   0.156250         inf       0.833333
# 5   0.093750         inf       0.500000
# 6   0.125000         inf       0.666667
# 7   0.062500         inf       0.333333
# 8   0.125000         inf       0.666667
# 9   0.062500         inf       0.333333
# 10  0.156250         inf       0.833333
# 11  0.125000         inf       0.666667
# 12  0.125000         inf       0.666667
# 13  0.125000         inf       0.666667
# 14  0.093750         inf       0.500000
# 15  0.125000         inf       0.666667
# 16  0.125000         inf       0.666667
# 17  0.093750         inf       0.500000
# 18  0.062500         inf       0.333333
# 19  0.125000         inf       0.666667
# 20  0.187500         inf       1.000000
# 21  0.187500         inf       1.000000
# 22  0.062500         inf       0.333333

# %% [markdown]
# # reference
# - [Associative Classification in Data Mining - GeeksforGeeks](https://www.geeksforgeeks.org/associative-classification-in-data-mining/)
# - [Comparative Analysis Between Apriori and Fp Growth | Kaggle](https://www.kaggle.com/code/keitazoumana/comparative-analysis-between-apriori-and-fp-growth)
# = [Apriori — Association Rule Mining In-depth Explanation and Python Implementation | by Chonyy | Towards Data Science](https://towardsdatascience.com/apriori-association-rule-mining-explanation-and-python-implementation-290b42afdfc6)
# - mlxtend doc
#     - [Apriori - mlxtend (rasbt.github.io)](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/)
#     - [Association rules - mlxtend (rasbt.github.io)](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/)
#     - [Fpgrowth - mlxtend (rasbt.github.io)](https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/fpgrowth/)
